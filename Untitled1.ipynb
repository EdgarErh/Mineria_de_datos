# %% [markdown]
# <a href="https://colab.research.google.com/github/EdgarErh/Mineria_de_datos/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mineria de datos

# %% [markdown]
# ##Primer parcial

# %% [markdown]
# ### Introducción

# %% [markdown]
# #### Conceptos

# %% [markdown]
# #### Ciencia de datos

# %% [markdown]
# ##### Understanding Data Types in Python

# %%
##importa numpy y lo renombra como np
import numpy as np

# %%
##areglo lineal de enteros
np.array([1, 4, 2, 5, 3])
# Out:
# array([1, 4, 2, 5, 3])

# %%
##castea los numeros a flotantes
np.array([3.14, 4, 2, 3])
# Out:
# array([3.14, 4.  , 2.  , 3.  ])

# %%
np.array([1, 2, 3, 4], dtype='float32')
# Out:
# array([1., 2., 3., 4.], dtype=float32)

# %%
np.array([1, 2, 3, 4], dtype='int')
# Out:
# array([1, 2, 3, 4])

# %%
#genera matriz bidi desde i en rangos de i + 3
np.array([range(i, i + 3) for i in [2, 4, 6]])
# Out:
# array([[2, 3, 4],
#        [4, 5, 6],
#        [6, 7, 8]])

# %% [markdown]
# #####IPython Magic Commands

# %%
##Sirve para evaluar el desempeño de expresión en cuanto a tiempo
# %timeit L = [n ** 2 for n in range(1000)]
# Out:
# 167 µs ± 55.5 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
##sirve para evaluar el desempoelo de expresión en cuanto a tiempo en mas
#de una linea de código
# %%timeit
L = []
for n in range(1000):
  L.append(n ** 2)
# Out:
# 76.1 µs ± 830 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# #####Help and documentacion in IPhyton

# %% [markdown]
# #####IPython and Shell Commands

# %%
# !la
# Out:
# /bin/bash: line 1: la: command not found

# %%
# !pwd
# Out:
# /content

# %%
# !echo "printing from the shell"
# Out:
# printing from the shell

# %%
contents = !ls

# %%
print(contents)
# Out:
# ['sample_data']

# %%
directory = !pwd

# %%
print(directory)
# Out:
# ['/content']

# %%
type(directory)
# Out:
# IPython.utils.text.SList

# %%
message = "hello from Python"

# %%
# !echo {message}
# Out:
# hello from Python

# %%
# %cd /content
# Out:
# /content

# %%
# %ls
# Out:
# sample_data/

# %%
# %cd sample_data/
# Out:
# /content/sample_data

# %%
# %ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
# %cat
# Out:
# ^C

# %% [markdown]
# #### Mineria de datos

# %% [markdown]
# La Mineria de datos: es un proceso para analizar datos en volumenes, esto sirve para descubrir patrones, tendencias y correlaciones ocultas, asi de esta manera se transforma la información cruda en conocimiento util para predecir y tomar decisiones con estrategia en negocios o grandes empresas, ayudando al futuro de estas en cuanto a ventas o avances dentro de ellas.
