# %% [markdown]
# <a href="https://colab.research.google.com/github/EdgarErh/Mineria_de_datos/blob/main/Examen_Parcial_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pregunta 2

# %%
#Edgar Omar Rodriguez Hernandez 177888
from google.colab import files
import pandas as pd

uploaded = files.upload()
df = pd.read_csv('items.csv')
# Out:
#      <input type="file" id="files-c096fe63-fb78-4a2f-93b7-9f3228e95773" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c096fe63-fb78-4a2f-93b7-9f3228e95773">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.eval('importe = precio * cantidad', inplace=True)

dfa = df.query("categoria == 'A'")

promedios = df.groupby('categoria')['importe'].mean()

print("DataFrame con la columna 'importe':")
print(df)
print("\nPromedios por categoría:")
print(promedios)

print(f"\nRespuesta numérica: {promedios['A']:.3f}")
# Out:
# DataFrame con la columna 'importe':
#   categoria item  precio  cantidad  importe
# 0         A    x     100         2      200
# 1         A    y     250         1      250
# 2         B    z      80         5      400
# 3         B    w     120         3      360
# 4         A    k     200         2      400
#
# Promedios por categoría:
# categoria
# A    283.333333
# B    380.000000
# Name: importe, dtype: float64
#
# Respuesta numérica: 283.333

# %% [markdown]
# Pregunta 3

# %%
uploaded = files.upload()

dfc = pd.read_csv('clientes.csv')
dfo = pd.read_csv('ordenes.csv')

df_res = pd.merge(dfc, dfo, on='cliente_id', how='left')

total_filas = len(df_res)

monto_por_cliente = df_res.groupby('cliente_id')['monto'].sum().fillna(0)

print(f"Número total de filas: {total_filas}")
print("Monto total por cliente:")
monto_por_cliente
# Out:
#      <input type="file" id="files-05157b65-8f8f-4c03-aa56-55c4a05ea417" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-05157b65-8f8f-4c03-aa56-55c4a05ea417">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Pregunta 4

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-51a0b24f-6940-4d42-acf6-a57dab6d3485" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51a0b24f-6940-4d42-acf6-a57dab6d3485">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('sensores.csv')
df = df[['ts', 'temperatura', 'humedad']]

df['ts'] = pd.to_datetime(df['ts'], format='mixed', errors='coerce')

mediana_temp = df['temperatura'].median()
df['temperatura'] = df['temperatura'].fillna(mediana_temp)

media_hum = df['humedad'].mean()
df['humedad'] = df['humedad'].fillna(media_hum)

nat_en_ts = df['ts'].isna().sum()
mediana_final_temp = df['temperatura'].median()
media_final_hum = df['humedad'].mean()

print(f"(a) NaT en ts: {nat_en_ts}")
print(f"(b) Mediana final temperatura: {mediana_final_temp:.1f}")
print(f"(c) Media final humedad: {media_final_hum:.3f}")
# Out:
# (a) NaT en ts: 0
# (b) Mediana final temperatura: 22.8
# (c) Media final humedad: 46.167
